# %%
import pandas as pd
pd.options.display.max_columns = None
import pandas_profiling as pp
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
tanzania_indicators_bitenriched = pd.read_csv("Tanzania_indicators_bitEnriched_c20181120.csv")

# %%
tanzania_indicators_bitenriched.sample(5).T
# Out:
#                                                          304       364  \
# geoUnit                                               Dodoma    Kagera
# Year                                                    1999      2003
# geoLevel                                              Region    Region
# geoGroup                                            Tanzania  Tanzania
# Gender                                                  Both      Both
# Age                                                      All       All
# RegionArea                                             41311     25265
# VLNS                                                     NaN       NaN
# VLNS_num                                                 NaN       NaN
# VLS                                                      NaN       NaN
# VLS_num                                                  NaN       NaN
# HCTS                                                     NaN       NaN
# lat                                                 -6.57382  -2.37511
# lon                                                  36.2631   31.2626
# Population                                               NaN       NaN
# ART2coverage                                             NaN       NaN
# Water_spendingPerCapita                                  NaN       NaN
# Unigold.HIV.1.2_Test_Eligible                            NaN       NaN
# Roads_spendingPerCapita                                  NaN       NaN
# HIV.AIDS_spendingPerCapita                               NaN       NaN
# CumNumPersNotOnART_perc                                  NaN       NaN
# Agriculture_spendingPerCapita                            NaN       NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN       NaN
# HIVprevalence_num                                        NaN       NaN
# Efavirenz.600Mg.Tablets_Treatment_Eligible               NaN       NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN       NaN
# Nevirapine.Oral.Solution_Treatment_Stockout              NaN       NaN
# Nevirapine.Oral.Solution_Treatment_Available             NaN       NaN
# Determine.HIV.1.2_Test_Stockout                          NaN       NaN
# Determine.HIV.1.2_Test_Unavailable                       NaN       NaN
# ...                                                      ...       ...
# Determine.HIV.1.2_Test_Available                         NaN       NaN
# HIVprevalence                                            NaN       NaN
# Unigold.HIV.1.2_Test_Unavailable                         NaN       NaN
# VCTHIVposCases_new                                       392       205
# VCTHIVpos_new_perc                                         0      33.2
# Determine.HIV.1.2_Test_Eligible                          NaN       NaN
# CumNumPersOnART                                          NaN       NaN
# Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct        NaN       NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN       NaN
# Others_spendingPerCapita                                 NaN       NaN
# Unigold.HIV.1.2_Test_Unavailable_pct                     NaN       NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN       NaN
# Unigold.HIV.1.2_Test_Stockout                            NaN       NaN
# Nevirapine.Oral.Solution_Treatment_Eligible              NaN       NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN       NaN
# Determine.HIV.1.2_Test_Unavailable_pct                   NaN       NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN       NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN       NaN
# Administration_spendingPerCapita                         NaN       NaN
# rptHIVcases                                             2748     12034
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN       NaN
# Nevirapine.Oral.Solution_Treatment_Unavailable           NaN       NaN
# VCcases_oldNew                                           NaN       NaN
# CumNumPersEnrolledInHIV                                  NaN       NaN
# Efavirenz.600Mg.Tablets_Treatment_Available              NaN       NaN
# Health_spendingPerCapita                                 NaN       NaN
# CurrNumPersOnART                                         NaN       NaN
# Unigold.HIV.1.2_Test_Available                           NaN       NaN
# VCTcases_new                                            1860       617
# NumPersPerSqKm                                           NaN       NaN
#
#                                                          767          128  \
# geoUnit                                               Tabora     Morogoro
# Year                                                    1989         2017
# geoLevel                                              Region       Region
# geoGroup                                            Tanzania     Tanzania
# Gender                                                  Both         Both
# Age                                                      All          All
# RegionArea                                             76150        70624
# VLNS                                                     NaN      17.1504
# VLNS_num                                                 NaN           65
# VLS                                                      NaN      82.8496
# VLS_num                                                  NaN          314
# HCTS                                                     NaN      32.2176
# lat                                                 -5.11076     -8.23064
# lon                                                  32.7181      36.9541
# Population                                               NaN  1.93252e+06
# ART2coverage                                             NaN        0.071
# Water_spendingPerCapita                                  NaN      1681.82
# Unigold.HIV.1.2_Test_Eligible                            NaN         2880
# Roads_spendingPerCapita                                  NaN      304.384
# HIV.AIDS_spendingPerCapita                               NaN      238.862
# CumNumPersNotOnART_perc                                  NaN       54.654
# Agriculture_spendingPerCapita                            NaN      1692.64
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN          266
# HIVprevalence_num                                        NaN      90599.9
# Efavirenz.600Mg.Tablets_Treatment_Eligible               NaN          923
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN          776
# Nevirapine.Oral.Solution_Treatment_Stockout              NaN          379
# Nevirapine.Oral.Solution_Treatment_Available             NaN         2221
# Determine.HIV.1.2_Test_Stockout                          NaN          245
# Determine.HIV.1.2_Test_Unavailable                       NaN          145
# ...                                                      ...          ...
# Determine.HIV.1.2_Test_Available                         NaN         2267
# HIVprevalence                                            NaN          4.2
# Unigold.HIV.1.2_Test_Unavailable                         NaN          121
# VCTHIVposCases_new                                       NaN          NaN
# VCTHIVpos_new_perc                                       NaN          NaN
# Determine.HIV.1.2_Test_Eligible                          NaN         2412
# CumNumPersOnART                                          NaN          NaN
# Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct        NaN     0.157096
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN          166
# Others_spendingPerCapita                                 NaN          NaN
# Unigold.HIV.1.2_Test_Unavailable_pct                     NaN    0.0420139
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN         2516
# Unigold.HIV.1.2_Test_Stockout                            NaN          194
# Nevirapine.Oral.Solution_Treatment_Eligible              NaN         2534
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN    0.0659777
# Determine.HIV.1.2_Test_Unavailable_pct                   NaN    0.0601161
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN          155
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN     0.166488
# Administration_spendingPerCapita                         NaN          NaN
# rptHIVcases                                              525          NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN         2350
# Nevirapine.Oral.Solution_Treatment_Unavailable           NaN          313
# VCcases_oldNew                                           NaN          NaN
# CumNumPersEnrolledInHIV                                  NaN          NaN
# Efavirenz.600Mg.Tablets_Treatment_Available              NaN          778
# Health_spendingPerCapita                                 NaN          NaN
# CurrNumPersOnART                                         NaN          NaN
# Unigold.HIV.1.2_Test_Available                           NaN         2759
# VCTcases_new                                             NaN          NaN
# NumPersPerSqKm                                           NaN           27
#
#                                                          582
# geoUnit                                               Mtwara
# Year                                                    1994
# geoLevel                                              Region
# geoGroup                                            Tanzania
# Gender                                                  Both
# Age                                                      All
# RegionArea                                             16710
# VLNS                                                     NaN
# VLNS_num                                                 NaN
# VLS                                                      NaN
# VLS_num                                                  NaN
# HCTS                                                     NaN
# lat                                                 -10.7275
# lon                                                  39.1544
# Population                                               NaN
# ART2coverage                                             NaN
# Water_spendingPerCapita                                  NaN
# Unigold.HIV.1.2_Test_Eligible                            NaN
# Roads_spendingPerCapita                                  NaN
# HIV.AIDS_spendingPerCapita                               NaN
# CumNumPersNotOnART_perc                                  NaN
# Agriculture_spendingPerCapita                            NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN
# HIVprevalence_num                                        NaN
# Efavirenz.600Mg.Tablets_Treatment_Eligible               NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN
# Nevirapine.Oral.Solution_Treatment_Stockout              NaN
# Nevirapine.Oral.Solution_Treatment_Available             NaN
# Determine.HIV.1.2_Test_Stockout                          NaN
# Determine.HIV.1.2_Test_Unavailable                       NaN
# ...                                                      ...
# Determine.HIV.1.2_Test_Available                         NaN
# HIVprevalence                                            NaN
# Unigold.HIV.1.2_Test_Unavailable                         NaN
# VCTHIVposCases_new                                       NaN
# VCTHIVpos_new_perc                                       NaN
# Determine.HIV.1.2_Test_Eligible                          NaN
# CumNumPersOnART                                          NaN
# Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct        NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN
# Others_spendingPerCapita                                 NaN
# Unigold.HIV.1.2_Test_Unavailable_pct                     NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN
# Unigold.HIV.1.2_Test_Stockout                            NaN
# Nevirapine.Oral.Solution_Treatment_Eligible              NaN
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN
# Determine.HIV.1.2_Test_Unavailable_pct                   NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN
# Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg...       NaN
# Administration_spendingPerCapita                         NaN
# rptHIVcases                                             2201
# Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600M...       NaN
# Nevirapine.Oral.Solution_Treatment_Unavailable           NaN
# VCcases_oldNew                                           NaN
# CumNumPersEnrolledInHIV                                  NaN
# Efavirenz.600Mg.Tablets_Treatment_Available              NaN
# Health_spendingPerCapita                                 NaN
# CurrNumPersOnART                                         NaN
# Unigold.HIV.1.2_Test_Available                           NaN
# VCTcases_new                                             NaN
# NumPersPerSqKm                                           NaN
#
# [67 rows x 5 columns]

# %%
#pp.ProfileReport(tanzania_indicators_bitenriched).to_file(outputfile="tanzania_indicatos_report.html")

# %%
tanzania_indicators_bitenriched[tanzania_indicators_bitenriched.groupby("geoUnit")["Year"].apply(lambda x: x == 2016)].sample(10)
# Out:
#              geoUnit  Year geoLevel  geoGroup Gender  Age  RegionArea  \
# 67            Kigoma  2016   Region  Tanzania   Both  All     37040.0
# 77       Kilimanjaro  2016   Region  Tanzania   Both  All     13250.0
# 222           Tabora  2016   Region  Tanzania   Both  All     76150.0
# 372  Kaskazini Pemba  2016   Region  Tanzania   Both  All         NaN
# 52            Kagera  2016   Region  Tanzania   Both  All     25265.0
# 437     Kusini Pemba  2016   Region  Tanzania   Both  All         NaN
# 541  Mjini Magharibi  2016   Region  Tanzania   Both  All         NaN
# 147           Mwanza  2016   Region  Tanzania   Both  All      9467.0
# 192        Shinyanga  2016   Region  Tanzania   Both  All     18901.0
# 127         Morogoro  2016   Region  Tanzania   Both  All     70624.0
#
#            VLNS  VLNS_num        VLS  VLS_num       HCTS       lat        lon  \
# 67    15.542763     189.0  84.457237   1027.0  28.458333 -4.649795  30.527910
# 77    25.543361    1187.0  74.456639   3460.0  34.687500 -4.133693  37.808769
# 222   14.423077      45.0  85.576923    267.0  31.217140 -5.110756  32.718138
# 372  100.000000       0.0   0.000000      0.0        NaN -5.031935  39.775557
# 52    11.420205     156.0  88.579795   1210.0  41.625000 -2.375112  31.262637
# 437  100.000000       0.0   0.000000      0.0        NaN -5.314696  39.754951
# 541   60.156250     154.0  39.843750    102.0        NaN -6.229814  39.258329
# 147   10.011809     763.0  89.988191   6858.0  31.773663 -2.878003  32.718138
# 192   13.881402     103.0  86.118598    639.0  38.694444 -3.663930  33.421180
# 127  100.000000       0.0   0.000000      0.0  29.239198 -8.230643  36.954107
#
#      Population  ART2coverage  Water_spendingPerCapita  \
# 67    2342300.0        0.0270              1510.285368
# 77    1759000.0        0.0530              2459.098367
# 222   2576100.0        0.0240              1362.178298
# 372         NaN           NaN                      NaN
# 52    2789600.0        0.0210              1967.829964
# 437         NaN           NaN                      NaN
# 541         NaN           NaN                      NaN
# 147   3123000.0        0.0320              1265.956039
# 192   1666600.0        0.0096              2123.676520
# 127   2437400.0        0.0730              1681.822413
#
#      Unigold.HIV.1.2_Test_Eligible  Roads_spendingPerCapita  \
# 67                          2335.0               708.177260
# 77                          2366.0              1178.111882
# 222                         2103.0              1823.762533
# 372                            NaN                      NaN
# 52                          1812.0              1576.006907
# 437                            NaN                      NaN
# 541                            NaN                      NaN
# 147                         2321.0              2272.258131
# 192                         1634.0              1705.718079
# 127                         2549.0               304.384014
#
#      HIV.AIDS_spendingPerCapita  CumNumPersNotOnART_perc  \
# 67                   303.789650                57.969705
# 77                   571.071183                42.558365
# 222                  279.203190                46.183559
# 372                         NaN                      NaN
# 52                   342.119220                42.313735
# 437                         NaN                      NaN
# 541                         NaN                      NaN
# 147                  248.467450                47.885889
# 192                  342.119220                40.425378
# 127                  259.524033                54.653967
#
#      Agriculture_spendingPerCapita  \
# 67                     2704.303214
# 77                     3398.967196
# 222                    2485.807682
# 372                            NaN
# 52                     3055.379670
# 437                            NaN
# 541                            NaN
# 147                    2006.575776
# 192                    3377.809549
# 127                    1692.637627
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Stockout  \
# 67                                               353.0
# 77                                                60.0
# 222                                              132.0
# 372                                                NaN
# 52                                                57.0
# 437                                                NaN
# 541                                                NaN
# 147                                              139.0
# 192                                               53.0
# 127                                              230.0
#
#      HIVprevalence_num  Efavirenz.600Mg.Tablets_Treatment_Eligible  \
# 67        70373.750000                                      1348.0
# 77        87469.000000                                      1278.0
# 222      116445.000000                                      1018.0
# 372                NaN                                         NaN
# 52        45231.000000                                       888.0
# 437                NaN                                         NaN
# 541                NaN                                         NaN
# 147      116445.000000                                      1277.0
# 192       45231.000000                                       743.0
# 127       90599.854167                                      1149.0
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Available  \
# 67                                               779.0
# 77                                              1200.0
# 222                                              825.0
# 372                                                NaN
# 52                                               814.0
# 437                                                NaN
# 541                                                NaN
# 147                                             1113.0
# 192                                              583.0
# 127                                              934.0
#
#      Nevirapine.Oral.Solution_Treatment_Stockout  \
# 67                                         440.0
# 77                                         162.0
# 222                                        181.0
# 372                                          NaN
# 52                                         103.0
# 437                                          NaN
# 541                                          NaN
# 147                                        171.0
# 192                                         39.0
# 127                                        250.0
#
#      Nevirapine.Oral.Solution_Treatment_Available  \
# 67                                         1734.0
# 77                                         1986.0
# 222                                        1732.0
# 372                                           NaN
# 52                                         1619.0
# 437                                           NaN
# 541                                           NaN
# 147                                        2022.0
# 192                                        1496.0
# 127                                        2115.0
#
#      Determine.HIV.1.2_Test_Stockout  Determine.HIV.1.2_Test_Unavailable  \
# 67                             591.0                               578.0
# 77                              92.0                               120.0
# 222                            351.0                               376.0
# 372                              NaN                                 NaN
# 52                              39.0                               -20.0
# 437                              NaN                                 NaN
# 541                              NaN                                 NaN
# 147                            407.0                               362.0
# 192                            131.0                               210.0
# 127                            311.0                               298.0
#
#      Nevirapine.Oral.Solution_Treatment_Unavailable_pct  \
# 67                                            0.223466
# 77                                            0.093978
# 222                                           0.137450
# 372                                                NaN
# 52                                            0.068470
# 437                                                NaN
# 541                                                NaN
# 147                                           0.069917
# 192                                           0.085015
# 127                                           0.082827
#
#      Efavirenz.600Mg.Tablets_Treatment_Stockout    ANCSTR  \
# 67                                        545.0  0.190789
# 77                                         63.0  1.000000
# 222                                       172.0  0.487568
# 372                                         NaN       NaN
# 52                                         91.0  0.779487
# 437                                         NaN       NaN
# 541                                         NaN       NaN
# 147                                       391.0  0.700815
# 192                                       173.0  0.597240
# 127                                       323.0  0.376884
#
#      Efavirenz.600Mg.Tablets_Treatment_Unavailable  \
# 67                                           499.0
# 77                                            51.0
# 222                                          151.0
# 372                                            NaN
# 52                                            80.0
# 437                                            NaN
# 541                                            NaN
# 147                                          177.0
# 192                                          169.0
# 127                                          225.0
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Stockout  \
# 67                                               587.0
# 77                                                65.0
# 222                                              169.0
# 372                                                NaN
# 52                                                85.0
# 437                                                NaN
# 541                                                NaN
# 147                                              375.0
# 192                                              154.0
# 127                                              306.0
#
#       VCcases_new  \
# 67   28039.666667
# 77            NaN
# 222           NaN
# 372           NaN
# 52            NaN
# 437           NaN
# 541           NaN
# 147  37433.000000
# 192           NaN
# 127           NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Eligible  \
# 67                                              1336.0
# 77                                              1287.0
# 222                                              985.0
# 372                                                NaN
# 52                                               877.0
# 437                                                NaN
# 541                                                NaN
# 147                                             1301.0
# 192                                              761.0
# 127                                             1140.0
#
#      Determine.HIV.1.2_Test_Available  HIVprevalence  \
# 67                             1591.0           3.40
# 77                             1736.0           4.90
# 222                            1428.0           5.10
# 372                               NaN            NaN
# 52                             1257.0           5.45
# 437                               NaN            NaN
# 541                               NaN            NaN
# 147                            1565.0           5.70
# 192                            1167.0            NaN
# 127                            1996.0           4.90
#
#      Unigold.HIV.1.2_Test_Unavailable  VCTHIVposCases_new  VCTHIVpos_new_perc  \
# 67                              326.0             15561.0            4.433333
# 77                              126.0                 NaN                 NaN
# 222                             287.0                 NaN                 NaN
# 372                               NaN                 NaN                 NaN
# 52                               60.0                 NaN                 NaN
# 437                               NaN                 NaN                 NaN
# 541                               NaN                 NaN                 NaN
# 147                             231.0             59150.5           13.550000
# 192                             183.0                 NaN                 NaN
# 127                             184.0                 NaN                 NaN
#
#      Determine.HIV.1.2_Test_Eligible  CumNumPersOnART  \
# 67                            2169.0      5126.000000
# 77                            1856.0              NaN
# 222                           1804.0              NaN
# 372                              NaN              NaN
# 52                            1237.0              NaN
# 437                              NaN              NaN
# 541                              NaN              NaN
# 147                           1927.0     30283.333333
# 192                           1377.0              NaN
# 127                           2294.0              NaN
#
#      Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct  \
# 67                                            0.370178
# 77                                            0.039906
# 222                                           0.148330
# 372                                                NaN
# 52                                            0.090090
# 437                                                NaN
# 541                                                NaN
# 147                                           0.138606
# 192                                           0.227456
# 127                                           0.195822
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable  \
# 67                                               377.0
# 77                                               105.0
# 222                                              201.0
# 372                                                NaN
# 52                                                66.0
# 437                                                NaN
# 541                                                NaN
# 147                                              104.0
# 192                                              140.0
# 127                                              135.0
#
#      Others_spendingPerCapita  Unigold.HIV.1.2_Test_Unavailable_pct  \
# 67               11691.576280                              0.139615
# 77                        NaN                              0.053254
# 222                       NaN                              0.136472
# 372                       NaN                                   NaN
# 52                        NaN                              0.033113
# 437                       NaN                                   NaN
# 541                       NaN                                   NaN
# 147               7034.157743                              0.099526
# 192                       NaN                              0.111995
# 127                       NaN                              0.072185
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Eligible  \
# 67                                              2199.0
# 77                                              2166.0
# 222                                             1975.0
# 372                                                NaN
# 52                                              1722.0
# 437                                                NaN
# 541                                                NaN
# 147                                             2156.0
# 192                                             1594.0
# 127                                             2205.0
#
#      Unigold.HIV.1.2_Test_Stockout  \
# 67                           309.0
# 77                            54.0
# 222                          186.0
# 372                            NaN
# 52                            51.0
# 437                            NaN
# 541                            NaN
# 147                          212.0
# 192                          101.0
# 127                          202.0
#
#      Nevirapine.Oral.Solution_Treatment_Eligible  \
# 67                                        2233.0
# 77                                        2192.0
# 222                                       2008.0
# 372                                          NaN
# 52                                        1738.0
# 437                                          NaN
# 541                                          NaN
# 147                                       2174.0
# 192                                       1635.0
# 127                                       2306.0
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct  \
# 67                                            0.171442
# 77                                            0.048476
# 222                                           0.101772
# 372                                                NaN
# 52                                            0.038328
# 437                                                NaN
# 541                                                NaN
# 147                                           0.048237
# 192                                           0.087829
# 127                                           0.061224
#
#      Determine.HIV.1.2_Test_Unavailable_pct  \
# 67                                 0.266482
# 77                                 0.064655
# 222                                0.208426
# 372                                     NaN
# 52                                -0.016168
# 437                                     NaN
# 541                                     NaN
# 147                                0.187857
# 192                                0.152505
# 127                                0.129904
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable  \
# 67                                               557.0
# 77                                                87.0
# 222                                              160.0
# 372                                                NaN
# 52                                                63.0
# 437                                                NaN
# 541                                                NaN
# 147                                              188.0
# 192                                              178.0
# 127                                              206.0
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable_pct  \
# 67                                            0.416916
# 77                                            0.067599
# 222                                           0.162437
# 372                                                NaN
# 52                                            0.071836
# 437                                                NaN
# 541                                                NaN
# 147                                           0.144504
# 192                                           0.233903
# 127                                           0.180702
#
#      Administration_spendingPerCapita  rptHIVcases  \
# 67                                NaN          NaN
# 77                                NaN          NaN
# 222                               NaN          NaN
# 372                               NaN          NaN
# 52                                NaN          NaN
# 437                               NaN          NaN
# 541                               NaN          NaN
# 147                               NaN          NaN
# 192                               NaN          NaN
# 127                               NaN          NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Available  \
# 67                                              1822.0
# 77                                              2061.0
# 222                                             1774.0
# 372                                                NaN
# 52                                              1656.0
# 437                                                NaN
# 541                                                NaN
# 147                                             2052.0
# 192                                             1454.0
# 127                                             2070.0
#
#      Nevirapine.Oral.Solution_Treatment_Unavailable  VCcases_oldNew  \
# 67                                            499.0             NaN
# 77                                            206.0             NaN
# 222                                           276.0             NaN
# 372                                             NaN             NaN
# 52                                            119.0             NaN
# 437                                             NaN             NaN
# 541                                             NaN             NaN
# 147                                           152.0             NaN
# 192                                           139.0             NaN
# 127                                           191.0             NaN
#
#      CumNumPersEnrolledInHIV  Efavirenz.600Mg.Tablets_Treatment_Available  \
# 67                       NaN                                        849.0
# 77                       NaN                                       1227.0
# 222                      NaN                                        867.0
# 372                      NaN                                          NaN
# 52                       NaN                                        808.0
# 437                      NaN                                          NaN
# 541                      NaN                                          NaN
# 147                      NaN                                       1100.0
# 192                      NaN                                        574.0
# 127                      NaN                                        924.0
#
#      Health_spendingPerCapita  CurrNumPersOnART  \
# 67                        NaN               NaN
# 77                        NaN               NaN
# 222                       NaN               NaN
# 372                       NaN               NaN
# 52                        NaN               NaN
# 437                       NaN               NaN
# 541                       NaN               NaN
# 147                       NaN               NaN
# 192                       NaN               NaN
# 127                       NaN               NaN
#
#      Unigold.HIV.1.2_Test_Available  VCTcases_new  NumPersPerSqKm
# 67                           2009.0           NaN            63.0
# 77                           2240.0           NaN           133.0
# 222                          1816.0           NaN            34.0
# 372                             NaN           NaN             NaN
# 52                           1752.0           NaN           110.0
# 437                             NaN           NaN             NaN
# 541                             NaN           NaN             NaN
# 147                          2090.0           NaN           330.0
# 192                          1451.0           NaN            88.0
# 127                          2365.0           NaN            35.0

# %%
df_on_2016 = tanzania_indicators_bitenriched[tanzania_indicators_bitenriched.groupby("geoUnit")["Year"].apply(lambda x: x == 2016)]

# %%
df_on_2016.shape
# Out:
# (29, 67)

# %%
#plt.figure(figsize=(14,10))
#sns.heatmap(df_on_2016.isnull())

# %%
#pp.ProfileReport(df_on_2016).to_file(outputfile="df_after_2000.html")

# %% [markdown]
# ## Aura cleaning

# %%
cleaned_df = df_on_2016[['geoUnit', 'Year',
       'RegionArea', 'VLNS', 'VLNS_num', 'VLS', 'VLS_num', 'HCTS', 'Population', 'ART2coverage',
       'Unigold.HIV.1.2_Test_Eligible', 'CumNumPersNotOnART_perc',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'HIVprevalence_num', 'Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Available',
       'Determine.HIV.1.2_Test_Stockout',
       'Determine.HIV.1.2_Test_Unavailable',
       'Nevirapine.Oral.Solution_Treatment_Unavailable_pct',
       'Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Stockout',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Eligible', 'HIVprevalence',
       'Unigold.HIV.1.2_Test_Unavailable', 'CumNumPersOnART',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable', 'Unigold.HIV.1.2_Test_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Unigold.HIV.1.2_Test_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Eligible',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Determine.HIV.1.2_Test_Unavailable_pct',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable_pct', 'rptHIVcases',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Unavailable',
       'CumNumPersEnrolledInHIV',
       'Efavirenz.600Mg.Tablets_Treatment_Available',
       'Health_spendingPerCapita', 'CurrNumPersOnART',
       'Unigold.HIV.1.2_Test_Available', 'VCTcases_new', 'NumPersPerSqKm']]

# %%
cleaned_df.tail(10)
# Out:
#              geoUnit  Year  RegionArea        VLNS  VLNS_num         VLS  \
# 182           Ruvuma  2016     63669.0   18.860699     394.0   81.139301
# 192        Shinyanga  2016     18901.0   13.881402     103.0   86.118598
# 197           Simiyu  2016     25212.0  100.000000       0.0    0.000000
# 207          Singida  2016     49340.0  100.000000       0.0    0.000000
# 212           Songwe  2016         NaN         NaN       NaN         NaN
# 222           Tabora  2016     76150.0   14.423077      45.0   85.576923
# 232            Tanga  2016     26677.0    0.000000       0.0  100.000000
# 372  Kaskazini Pemba  2016         NaN  100.000000       0.0    0.000000
# 437     Kusini Pemba  2016         NaN  100.000000       0.0    0.000000
# 541  Mjini Magharibi  2016         NaN   60.156250     154.0   39.843750
#
#      VLS_num       HCTS   Population  ART2coverage  \
# 182   1695.0  31.212665  1498800.000        0.0190
# 192    639.0  38.694444  1666600.000        0.0096
# 197      0.0  39.953704  1705200.000        0.0270
# 207      0.0  38.457948  1504000.000        0.0230
# 212      NaN  40.583333  1816449.125        0.0054
# 222    267.0  31.217140  2576100.000        0.0240
# 232      4.0  29.400621  2236100.000        0.0340
# 372      0.0        NaN          NaN           NaN
# 437      0.0        NaN          NaN           NaN
# 541    102.0        NaN          NaN           NaN
#
#      Unigold.HIV.1.2_Test_Eligible  CumNumPersNotOnART_perc  \
# 182                         2391.0                44.254120
# 192                         1634.0                40.425378
# 197                         1557.0                42.313735
# 207                         1948.0                37.927885
# 212                         1285.0                41.912085
# 222                         2103.0                46.183559
# 232                         2635.0                54.653967
# 372                            NaN                      NaN
# 437                            NaN                      NaN
# 541                            NaN                      NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Stockout  \
# 182                                              151.0
# 192                                               53.0
# 197                                               73.0
# 207                                               66.0
# 212                                              118.0
# 222                                              132.0
# 232                                              266.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      HIVprevalence_num  Efavirenz.600Mg.Tablets_Treatment_Eligible  \
# 182       75785.500000                                      1247.0
# 192       45231.000000                                       743.0
# 197       45231.000000                                       688.0
# 207       47362.250000                                       480.0
# 212       71950.500000                                       538.0
# 222      116445.000000                                      1018.0
# 232       90599.854167                                      1303.0
# 372                NaN                                         NaN
# 437                NaN                                         NaN
# 541                NaN                                         NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Available  \
# 182                                              995.0
# 192                                              583.0
# 197                                              597.0
# 207                                              450.0
# 212                                              414.0
# 222                                              825.0
# 232                                              999.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Nevirapine.Oral.Solution_Treatment_Stockout  \
# 182                                        171.0
# 192                                         39.0
# 197                                         92.0
# 207                                         74.0
# 212                                        130.0
# 222                                        181.0
# 232                                        273.0
# 372                                          NaN
# 437                                          NaN
# 541                                          NaN
#
#      Nevirapine.Oral.Solution_Treatment_Available  \
# 182                                        2042.0
# 192                                        1496.0
# 197                                        1349.0
# 207                                        1761.0
# 212                                        1009.0
# 222                                        1732.0
# 232                                        2088.0
# 372                                           NaN
# 437                                           NaN
# 541                                           NaN
#
#      Determine.HIV.1.2_Test_Stockout  Determine.HIV.1.2_Test_Unavailable  \
# 182                            343.0                               378.0
# 192                            131.0                               210.0
# 197                             96.0                               121.0
# 207                            186.0                               223.0
# 212                             53.0                                73.0
# 222                            351.0                               376.0
# 232                            536.0                               431.0
# 372                              NaN                                 NaN
# 437                              NaN                                 NaN
# 541                              NaN                                 NaN
#
#      Nevirapine.Oral.Solution_Treatment_Unavailable_pct  \
# 182                                           0.113715
# 192                                           0.085015
# 197                                           0.085424
# 207                                           0.048108
# 212                                           0.121080
# 222                                           0.137450
# 232                                           0.117498
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Efavirenz.600Mg.Tablets_Treatment_Stockout  \
# 182                                       281.0
# 192                                       173.0
# 197                                       116.0
# 207                                        53.0
# 212                                       145.0
# 222                                       172.0
# 232                                       468.0
# 372                                         NaN
# 437                                         NaN
# 541                                         NaN
#
#      Efavirenz.600Mg.Tablets_Treatment_Unavailable  \
# 182                                          238.0
# 192                                          169.0
# 197                                           84.0
# 207                                           56.0
# 212                                          145.0
# 222                                          151.0
# 232                                          344.0
# 372                                            NaN
# 437                                            NaN
# 541                                            NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Stockout  \
# 182                                              285.0
# 192                                              154.0
# 197                                              113.0
# 207                                               63.0
# 212                                              134.0
# 222                                              169.0
# 232                                              463.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Eligible  \
# 182                                             1235.0
# 192                                              761.0
# 197                                              695.0
# 207                                              516.0
# 212                                              546.0
# 222                                              985.0
# 232                                             1324.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      HIVprevalence  Unigold.HIV.1.2_Test_Unavailable  CumNumPersOnART  \
# 182       6.300000                             244.0              NaN
# 192            NaN                             183.0              NaN
# 197       4.033333                             121.0              NaN
# 207       3.300000                             122.0              NaN
# 212       4.255556                              57.0     43537.333333
# 222       5.100000                             287.0              NaN
# 232            NaN                             228.0              NaN
# 372            NaN                               NaN              NaN
# 437            NaN                               NaN              NaN
# 541            NaN                               NaN              NaN
#
#      Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct  \
# 182                                           0.190858
# 192                                           0.227456
# 197                                           0.122093
# 207                                           0.116667
# 212                                           0.269517
# 222                                           0.148330
# 232                                           0.264006
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable  \
# 182                                              234.0
# 192                                              140.0
# 197                                              108.0
# 207                                               89.0
# 212                                              139.0
# 222                                              201.0
# 232                                              242.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Unigold.HIV.1.2_Test_Unavailable_pct  \
# 182                              0.102049
# 192                              0.111995
# 197                              0.077714
# 207                              0.062628
# 212                              0.044358
# 222                              0.136472
# 232                              0.086528
# 372                                   NaN
# 437                                   NaN
# 541                                   NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Eligible  \
# 182                                             2239.0
# 192                                             1594.0
# 197                                             1429.0
# 207                                             1841.0
# 212                                             1079.0
# 222                                             1975.0
# 232                                             2315.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Unigold.HIV.1.2_Test_Stockout  \
# 182                          168.0
# 192                          101.0
# 197                           75.0
# 207                          102.0
# 212                           31.0
# 222                          186.0
# 232                          214.0
# 372                            NaN
# 437                            NaN
# 541                            NaN
#
#      Nevirapine.Oral.Solution_Treatment_Eligible  \
# 182                                       2304.0
# 192                                       1635.0
# 197                                       1475.0
# 207                                       1850.0
# 212                                       1148.0
# 222                                       2008.0
# 232                                       2366.0
# 372                                          NaN
# 437                                          NaN
# 541                                          NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct  \
# 182                                           0.104511
# 192                                           0.087829
# 197                                           0.075577
# 207                                           0.048343
# 212                                           0.128823
# 222                                           0.101772
# 232                                           0.104536
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Determine.HIV.1.2_Test_Unavailable_pct  \
# 182                                0.180948
# 192                                0.152505
# 197                                0.084793
# 207                                0.125989
# 212                                0.075648
# 222                                0.208426
# 232                                0.180940
# 372                                     NaN
# 437                                     NaN
# 541                                     NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable  \
# 182                                              240.0
# 192                                              178.0
# 197                                               98.0
# 207                                               66.0
# 212                                              132.0
# 222                                              160.0
# 232                                              325.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable_pct  \
# 182                                           0.194332
# 192                                           0.233903
# 197                                           0.141007
# 207                                           0.127907
# 212                                           0.241758
# 222                                           0.162437
# 232                                           0.245468
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      rptHIVcases  \
# 182          NaN
# 192          NaN
# 197          NaN
# 207          NaN
# 212          NaN
# 222          NaN
# 232          NaN
# 372          NaN
# 437          NaN
# 541          NaN
#
#      Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Available  \
# 182                                             2005.0
# 192                                             1454.0
# 197                                             1321.0
# 207                                             1752.0
# 212                                              940.0
# 222                                             1774.0
# 232                                             2073.0
# 372                                                NaN
# 437                                                NaN
# 541                                                NaN
#
#      Nevirapine.Oral.Solution_Treatment_Unavailable  CumNumPersEnrolledInHIV  \
# 182                                           262.0                      NaN
# 192                                           139.0                      NaN
# 197                                           126.0                      NaN
# 207                                            89.0                      NaN
# 212                                           139.0                      NaN
# 222                                           276.0                      NaN
# 232                                           278.0                      NaN
# 372                                             NaN                      NaN
# 437                                             NaN                      NaN
# 541                                             NaN                      NaN
#
#      Efavirenz.600Mg.Tablets_Treatment_Available  Health_spendingPerCapita  \
# 182                                       1009.0                       NaN
# 192                                        574.0                       NaN
# 197                                        604.0                       NaN
# 207                                        424.0                       NaN
# 212                                        393.0                       NaN
# 222                                        867.0                       NaN
# 232                                        959.0                       NaN
# 372                                          NaN                       NaN
# 437                                          NaN                       NaN
# 541                                          NaN                       NaN
#
#      CurrNumPersOnART  Unigold.HIV.1.2_Test_Available  VCTcases_new  \
# 182               NaN                          2147.0           NaN
# 192               NaN                          1451.0           NaN
# 197               NaN                          1436.0           NaN
# 207               NaN                          1826.0           NaN
# 212               NaN                          1228.0           NaN
# 222               NaN                          1816.0           NaN
# 232               NaN                          2407.0           NaN
# 372               NaN                             NaN           NaN
# 437               NaN                             NaN           NaN
# 541               NaN                             NaN           NaN
#
#      NumPersPerSqKm
# 182            24.0
# 192            88.0
# 197            68.0
# 207            30.0
# 212             NaN
# 222            34.0
# 232            84.0
# 372             NaN
# 437             NaN
# 541             NaN

# %%
# reindex and clean up order numbers
cleaned_df.reset_index(inplace=True)
cleaned_df.drop(columns="index", inplace=True)
# Out:
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# these are not part of the mainland regions ! remove
# and no data in the other datasets from these island counties

cleaned_df.drop(index=[23, 26, 27, 28], inplace=True)
# Out:
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(cleaned_df == 0)

# %%
#generate a new report
pp.ProfileReport(cleaned_df).to_file(outputfile="cleaned_df.html")

# %% [markdown]
# ## Ceren request to do this again for 2017 & 2018 as well

# %%
df_on_2017 = tanzania_indicators_bitenriched[tanzania_indicators_bitenriched.groupby("geoUnit")["Year"].apply(lambda x: x == 2017)]
df_on_2018 = tanzania_indicators_bitenriched[tanzania_indicators_bitenriched.groupby("geoUnit")["Year"].apply(lambda x: x == 2018)]

# %%
cleaned_df_2017 = df_on_2017[['geoUnit', 'Year',
       'RegionArea', 'VLNS', 'VLNS_num', 'VLS', 'VLS_num', 'HCTS', 'Population', 'ART2coverage',
       'Unigold.HIV.1.2_Test_Eligible', 'CumNumPersNotOnART_perc',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'HIVprevalence_num', 'Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Available',
       'Determine.HIV.1.2_Test_Stockout',
       'Determine.HIV.1.2_Test_Unavailable',
       'Nevirapine.Oral.Solution_Treatment_Unavailable_pct',
       'Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Stockout',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Eligible', 'HIVprevalence',
       'Unigold.HIV.1.2_Test_Unavailable', 'CumNumPersOnART',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable', 'Unigold.HIV.1.2_Test_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Unigold.HIV.1.2_Test_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Eligible',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Determine.HIV.1.2_Test_Unavailable_pct',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable_pct', 'rptHIVcases',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Unavailable',
       'CumNumPersEnrolledInHIV',
       'Efavirenz.600Mg.Tablets_Treatment_Available',
       'Health_spendingPerCapita', 'CurrNumPersOnART',
       'Unigold.HIV.1.2_Test_Available', 'VCTcases_new', 'NumPersPerSqKm']]

# %%
cleaned_df_2018 = df_on_2018[['geoUnit', 'Year',
       'RegionArea', 'VLNS', 'VLNS_num', 'VLS', 'VLS_num', 'HCTS', 'Population', 'ART2coverage',
       'Unigold.HIV.1.2_Test_Eligible', 'CumNumPersNotOnART_perc',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'HIVprevalence_num', 'Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Available',
       'Determine.HIV.1.2_Test_Stockout',
       'Determine.HIV.1.2_Test_Unavailable',
       'Nevirapine.Oral.Solution_Treatment_Unavailable_pct',
       'Efavirenz.600Mg.Tablets_Treatment_Stockout',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Stockout',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Eligible', 'HIVprevalence',
       'Unigold.HIV.1.2_Test_Unavailable', 'CumNumPersOnART',
       'Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable', 'Unigold.HIV.1.2_Test_Unavailable_pct',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Eligible',
       'Unigold.HIV.1.2_Test_Stockout',
       'Nevirapine.Oral.Solution_Treatment_Eligible',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Unavailable_pct',
       'Determine.HIV.1.2_Test_Unavailable_pct',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable',
       'Zidovudine.60Mg.Lamivudine.30Mg.Nevirapine.50Mg.Tablets_Treatment_Unavailable_pct', 'rptHIVcases',
       'Tenofovir.300Mg.Lamivudine.300Mg.Efavirenz.600Mg.Tablets_Treatment_Available',
       'Nevirapine.Oral.Solution_Treatment_Unavailable',
       'CumNumPersEnrolledInHIV',
       'Efavirenz.600Mg.Tablets_Treatment_Available',
       'Health_spendingPerCapita', 'CurrNumPersOnART',
       'Unigold.HIV.1.2_Test_Available', 'VCTcases_new', 'NumPersPerSqKm']]

# %%
# reindex and clean up order numbers
cleaned_df_2017.reset_index(inplace=True)
cleaned_df_2017.drop(columns="index", inplace=True)

# reindex and clean up order numbers
cleaned_df_2018.reset_index(inplace=True)
cleaned_df_2018.drop(columns="index", inplace=True)
# Out:
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# these are not part of the mainland regions ! remove
# and no data in the other datasets from these island counties

cleaned_df_2017.drop(index=[23, 26, 27, 28], inplace=True)
cleaned_df_2018.drop(index=[23, 26, 27, 28], inplace=True)
# Out:
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(cleaned_df_2017 == 0)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(cleaned_df_2018 == 0)

# %% [markdown]
# ## let's start imputing some "zero's"

# %%
impute_value = cleaned_df[~((cleaned_df["VLNS"] == 100) | (cleaned_df["VLNS"] == 0))]["VLNS"].median()
impute_value
# Out:
# 15.167469598507349

# %%
x = cleaned_df[((cleaned_df["VLNS"] == 100) | (cleaned_df["VLNS"] == 0))]["VLNS"].index.values
x
# Out:
# array([ 2,  9, 10, 11, 13, 14, 21, 22, 25])

# %%
for i in x:
    cleaned_df["VLNS"].loc[i] = impute_value
# Out:
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/beire/anaconda2/envs/myenv3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#cleaned_df[((cleaned_df["VLNS"] == 100) | (cleaned_df["VLNS"] == 0))]["VLNS"].index
#cleaned_df.iloc[cleaned_df[((cleaned_df["VLNS"] == 100) | (cleaned_df["VLNS"] == 0))]["VLNS"].index] = impute_value

# %%
#((cleaned_df["VLNS"] == 100) | (cleaned_df["VLNS"] == 0)).value_counts()

# %%
cleaned_df["VLNS"]
# Out:
# 0     24.433249
# 1     43.187661
# 2     15.167470
# 3     12.770203
# 4     14.792176
# 5     11.420205
# 6      8.529412
# 7     15.542763
# 8     25.543361
# 9     15.167470
# 10    15.167470
# 11    15.167470
# 12    26.538430
# 13    15.167470
# 14    15.167470
# 15    10.011809
# 16    16.917293
# 17    14.311759
# 18    18.667505
# 19    18.860699
# 20    13.881402
# 21    15.167470
# 22    15.167470
# 24    14.423077
# 25    15.167470
# Name: VLNS, dtype: float64

# %% [markdown]
# ## we are going to apply this to 2 other Viral Load Columns

# %%
impute_value = cleaned_df[~((cleaned_df["VLNS_num"] == 100) | (cleaned_df["VLNS_num"] == 0))]["VLNS_num"].median()
impute_value
