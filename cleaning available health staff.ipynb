# %%
import pandas as pd

# %%
avail_health_staff = pd.read_csv("Available-Health-Staff-Skilled-and-Supporting-by-region-2014.csv")

# %%
avail_health_staff.columns = ['Region Cadre', 'Anaesthesiologists',
                              'Assistant Dental Officer',
       'Assistant Environmental Health Officer', 'Assistant Lab Tech',
       'Assistant Medical Officer', 'Assistant Nursing Officer',
       'Audiometrists', 'Chemist/Chemist Assistants',
       'Biomedical Technician/Technologist & Engineers', 'Clinical Assistant',
       'Clinical Officer', 'Conversation designation',
       'cook/Chef/catering Officer', 'Dental Assistants/Technologists',
       'Dental Therapist/Officers', 'Environmental Health Assistant',
       'Environmental Health Officer', 'Health Laboratory Assistant',
       'Health Laboratory Scientist',
       'Health Laboratory Technician/Technologists', 'Medical Recorders',
       'Health Secretary', 'ICT Profession', 'Laundry staff',
       'Medical Attendant', 'Medical Doctors',
       'Medical Specialist/Consultants', 'Nurses', 'Nursing Officer',
       'Nutrition Officer', 'Occupational Therapist Staff',
       'Optometric Technologist', 'Optometrist', 'Orthotist/Prosthetist',
       'Other Non0Medical Professionals', 'Pharmaceutical Technologist',
       'Pharmacist', 'Physiotherapist', 'Physiotherapist Assistant',
       'Prothetist/Orthotist', 'Radiologists & Radiologic Technologists',
       'Radiography staff', 'Radiotherapist', 'Researchers',
       'Speech Therapist', 'Sociol welfare Staff', 'Support Staff',
       'Technicians &Technologists', 'Tutors/Lecturers/Professor']

# %%
avail_health_staff["Year"] = 2014

# %%
avail_health_staff.sample(5).T
# Out:
#                                                    17       22     12  \
# Region Cadre                                    Pwani  Singida  Mbeya
# Anaesthesiologists                                  0        0      1
# Assistant Dental Officer                            6        5     14
# Assistant Environmental Health Officer             61       23     80
# Assistant Lab Tech                                 44       36    104
# Assistant Medical Officer                          59       48    141
# Assistant Nursing Officer                         114      113    379
# Audiometrists                                       0        0      0
# Chemist/Chemist Assistants                          0        1      0
# Biomedical Technician/Technologist & Engineers      1        1      1
# Clinical Assistant                                 41       34     99
# Clinical Officer                                  210      172    499
# ...

# %%
avail_health_staff_important = avail_health_staff[["Region Cadre",
                                                   "Year",
                                                   "Assistant Lab Tech",
                                                   "Assistant Medical Officer",
                                                  "Assistant Nursing Officer",
                                                  "Biomedical Technician/Technologist & Engineers",
                                                  "Clinical Assistant",
                                                  "Clinical Officer",
                                                  "Health Laboratory Assistant",
                                                  "Health Laboratory Scientist",
                                                  "Health Laboratory Technician/Technologists",
                                                  "Medical Recorders",
                                                  "Health Secretary",
                                                  "Medical Attendant",
                                                  "Medical Doctors",
                                                  "Medical Specialist/Consultants",
                                                  "Nurses",
                                                  "Nursing Officer",
                                                  "Nutrition Officer",
                                                  "Pharmaceutical Technologist",
                                                  "Pharmacist",
                                                  "Researchers",
                                                  "Support Staff",
                                                  "Technicians &Technologists"]]

# %%
avail_health_staff_important.sample(5).T
# Out:
#                                                      22      16     17  \
# Region Cadre                                    Singida  Njombe  Pwani
# Year                                               2014    2014   2014
# Assistant Lab Tech                                   36      34     44
# Assistant Medical Officer                            48      46     59
# Assistant Nursing Officer                           113     126    114
# Biomedical Technician/Technologist & Engineers        1       0      1
# Clinical Assistant                                   34      32     41
# Clinical Officer                                    172     164    210
# Health Laboratory Assistant                           1       2      2
# Health Laboratory Scientist                           0       0      3
# Health Laboratory Technician/Technologists           26      24     31
# Medical Recorders                                    13       6     16
# ...

# %%
avail_health_staff_important.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 24 columns):
# Region Cadre                                      25 non-null object
# Year                                              25 non-null int64
# Assistant Lab Tech                                25 non-null int64
# Assistant Medical Officer                         25 non-null int64
# Assistant Nursing Officer                         25 non-null int64
# Biomedical Technician/Technologist & Engineers    25 non-null int64
# Clinical Assistant                                25 non-null int64
# Clinical Officer                                  25 non-null int64
# Health Laboratory Assistant                       25 non-null int64
# Health Laboratory Scientist                       25 non-null int64
# Health Laboratory Technician/Technologists        25 non-null int64
# Medical Recorders                                 25 non-null int64
# ...

# %%
avail_health_staff_important.to_csv("more_cleaned_available_health_staff.csv", index=False)
